# %% [markdown]
# # Risk Models Using Tree-based Models
#
# Welcome to the second assignment of Course 2!

# %% [markdown]
# ## Outline
#
# - [1. Import Packages](#1)
# - [2. Load the Dataset](#2)
# - [3. Explore the Dataset](#3)
# - [4. Dealing with Missing Data](#4)
#     - [Exercise 1](#Ex-1)
# - [5. Decision Trees](#5)
#     - [Exercise 2](#Ex-2)
# - [6. Random Forests](#6)
#     - [Exercise 3](#Ex-3)
# - [7. Imputation](#7)
# - [8. Error Analysis](#8)
#     - [Exercise 4](#Ex-4)
# - [9. Imputation Approaches](#Ex-9)
#     - [Exercise 5](#Ex-5)
#     - [Exercise 6](#Ex-6)
# - [10. Comparison](#10)
# - [11. Explanations: SHAP](#)

# %% [markdown]
# In this assignment, you'll gain experience with tree based models by predicting the 10-year risk of death of individuals from the NHANES I epidemiology dataset (for a detailed description of this dataset you can check the [CDC Website](https://wwwn.cdc.gov/nchs/nhanes/nhefs/default.aspx/)). This is a challenging task and a great test bed for the machine learning methods we learned this week.
#
# As you go through the assignment, you'll learn about:
#
# - Dealing with Missing Data
#   - Complete Case Analysis.
#   - Imputation
# - Decision Trees
#   - Evaluation.
#   - Regularization.
# - Random Forests
#   - Hyperparameter Tuning.

# %% [markdown]
# <a name='1'></a>
# ## 1. Import Packages
#
# We'll first import all the common packages that we need for this assignment.
#
# - `shap` is a library that explains predictions made by machine learning models.
# - `sklearn` is one of the most popular machine learning libraries.
# - `itertools` allows us to conveniently manipulate iterable objects such as lists.
# - `pydotplus` is used together with `IPython.display.Image` to visualize graph structures such as decision trees.
# - `numpy` is a fundamental package for scientific computing in Python.
# - `pandas` is what we'll use to manipulate our data.
# - `seaborn` is a plotting library which has some convenient functions for visualizing missing data.
# - `matplotlib` is a plotting library.

# %%
import shap
import sklearn
import itertools
import pydotplus
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import Image 

from sklearn.tree import export_graphviz
#from sklearn.externals.six import StringIO
from six import StringIO
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer

# We'll also import some helper functions that will be useful later on.
from util import load_data, cindex

# %% [markdown]
# <a name='2'></a>
# ## 2. Load the Dataset

# %% [markdown]
# Run the next cell to load in the NHANES I epidemiology dataset. This dataset contains various features of hospital patients as well as their outcomes, i.e. whether or not they died within 10 years.

# %%
X_dev, X_test, y_dev, y_test = load_data(10)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# The dataset has been split into a development set (or dev set), which we will use to develop our risk models, and a test set, which we will use to test our models.
#
# We further split the dev set into a training and validation set, respectively to train and tune our models, using a 75/25 split (note that we set a random state to make this split repeatable).

# %%
X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, test_size=0.25, random_state=10)

# %% [markdown]
# <a name='3'></a>
# ## 3. Explore the Dataset
#
# The first step is to familiarize yourself with the data. Run the next cell to get the size of your training set and look at a small sample.

# %%
print("X_train shape: {}".format(X_train.shape))
X_train.head()
# Out:
# X_train shape: (5147, 18)
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 1599  43.0          84.0          637.0   1.0             49.3
# 2794  72.0          96.0          154.0   2.0             43.4
# 1182  54.0          78.0          205.0   1.0             43.8
# 6915  59.0          90.0          417.0   1.0             43.4
# 500   34.0          80.0          385.0   1.0             77.7
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 1599                10.0            5.0              253.0       134.0
# 2794                23.0            4.3              265.0       106.0
# 1182                12.0            4.2              206.0       180.0
# 6915                 9.0            4.5              327.0       114.0
# 500                  9.0            4.1              197.0        64.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 1599             1.59            7.7  1.0          NaN  490.0  27.3
# 2794             1.66            6.8  2.0        208.0  301.0  35.2
# 1182             1.67            6.6  2.0          NaN  363.0  49.6
# 6915             1.65            7.6  2.0          NaN  347.0  32.9
# 500              1.74            7.3  2.0          NaN  376.0  17.0
#
#       White blood cells        BMI  Pulse pressure
# 1599                9.1  25.803007            34.0
# 2794                6.0  33.394319           112.0
# 1182                5.9  20.278410            34.0
# 6915                6.1  32.917744            78.0
# 500                 8.2  30.743489            30.0

# %% [markdown]
# Our targets `y` will be whether or not the target died within 10 years. Run the next cell to see the target data series.

# %%
y_train.head(20)
# Out:
# 1599    False
# 2794     True
# 1182    False
# 6915    False
# 500     False
# 1188     True
# 9739    False
# 3266    False
# 6681    False
# 8822    False
# 5856     True
# 3415    False
# 9366    False
# 7975    False
# 1397    False
# 6809    False
# 9461    False
# 9374    False
# 1170     True
# 158     False
# Name: time, dtype: bool

# %% [markdown]
# Use the next cell to examine individual cases and familiarize yourself with the features.

# %%
i = 10
print(X_train.iloc[i,:])
print("\nDied within 10 years? {}".format(y_train.loc[y_train.index[i]]))
# Out:
# Age                    67.000000
# Diastolic BP           94.000000
# Poverty index         114.000000
# Race                    1.000000
# Red blood cells        43.800000
# Sedimentation rate     12.000000
# Serum Albumin           3.700000
# Serum Cholesterol     178.000000
# Serum Iron             73.000000
# Serum Magnesium         1.850000
# Serum Protein           7.000000
# Sex                     1.000000
# Systolic BP           140.000000
# TIBC                  311.000000
# TS                     23.500000
# White blood cells       4.300000
# BMI                    17.481227
# Pulse pressure         46.000000
# Name: 5856, dtype: float64
#
# Died within 10 years? True

# %% [markdown]
# <a name='4'></a>
# ## 4. Dealing with Missing Data
#
# Looking at our data in `X_train`, we see that some of the data is missing: some values in the output of the previous cell are marked as `NaN` ("not a number").
#
# Missing data is a common occurrence in data analysis, that can be due to a variety of reasons, such as measuring instrument malfunction, respondents not willing or not able to supply information, and errors in the data collection process.
#
# Let's examine the missing data pattern. `seaborn` is an alternative to `matplotlib` that has some convenient plotting functions for data analysis. We can use its `heatmap` function to easily visualize the missing data pattern.
#
# Run the cell below to plot the missing data:

# %%
sns.heatmap(X_train.isnull(), cbar=False)
plt.title("Training")
plt.show()

sns.heatmap(X_val.isnull(), cbar=False)
plt.title("Validation")
plt.show()

# %% [markdown]
# For each feature, represented as a column, values that are present are shown in black, and missing values are set in a light color.
#
# From this plot, we can see that many values are missing for systolic blood pressure (`Systolic BP`).

# %% [markdown]
# <a name='Ex-1'></a>
# ### Exercise 1
#
# In the cell below, write a function to compute the fraction of cases with missing data. This will help us decide how we handle this missing data in the future.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> The <code>pandas.DataFrame.isnull()</code> method is helpful in this case.</li>
#     <li> Use the <code>pandas.DataFrame.any()</code> method and set the <code>axis</code> parameter.</li>
#     <li> Divide the total number of rows with missing data by the total number of rows. Remember that in Python, <code>True</code> values are equal to 1.</li>
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def fraction_rows_missing(df):
    '''
    Return percent of rows with any missing
    data in the dataframe. 
    
    Input:
        df (dataframe): a pandas dataframe with potentially missing data
    Output:
        frac_missing (float): fraction of rows with missing data
    '''
    ### START CODE HERE (REPLACE 'Pass' with your 'return' code) ###
    return sum(df.isnull().any(axis = 1)) / len(df)
           
    ### END CODE HERE ###

# %% [markdown]
# Test your function by running the cell below.

# %%
df_test = pd.DataFrame({'a':[None, 1, 1, None], 'b':[1, None, 0, 1]})
print("Example dataframe:\n")
print(df_test)

print("\nComputed fraction missing: {}, expected: {}".format(fraction_rows_missing(df_test), 0.75))
print(f"Fraction of rows missing from X_train: {fraction_rows_missing(X_train):.3f}")
print(f"Fraction of rows missing from X_val: {fraction_rows_missing(X_val):.3f}")
print(f"Fraction of rows missing from X_test: {fraction_rows_missing(X_test):.3f}")
# Out:
# Example dataframe:
#
#      a    b
# 0  NaN  1.0
# 1  1.0  NaN
# 2  1.0  0.0
# 3  NaN  1.0
#
# Computed fraction missing: 0.75, expected: 0.75
# Fraction of rows missing from X_train: 0.699
# Fraction of rows missing from X_val: 0.704
# Fraction of rows missing from X_test: 0.000

# %% [markdown]
# We see that our train and validation sets have missing values, but luckily our test set has complete cases.

# %% [markdown]
# As a first pass, we will begin with a **complete case analysis**, dropping all of the rows with any missing data. Run the following cell to drop these rows from our train and validation sets.

# %%
X_train_dropped = X_train.dropna(axis='rows')
y_train_dropped = y_train.loc[X_train_dropped.index]
X_val_dropped = X_val.dropna(axis='rows')
y_val_dropped = y_val.loc[X_val_dropped.index]

# %% [markdown]
# <a name='5'></a>
# ## 5. Decision Trees
#
# Having just learned about decision trees, you choose to use a decision tree classifier. Use scikit-learn to build a decision tree for the hospital dataset using the train set.

# %%
dt = DecisionTreeClassifier(max_depth=None, random_state=10)
dt.fit(X_train_dropped, y_train_dropped)
# Out:
# DecisionTreeClassifier(random_state=10)

# %% [markdown]
# Next we will evaluate our model. We'll use C-Index for evaluation.
#
# > Remember from lesson 4 of week 1 that the C-Index evaluates the ability of a model to differentiate between different classes, by quantifying how often, when considering all pairs of patients (A, B), the model says that patient A has a higher risk score than patient B when, in the observed data, patient A actually died and patient B actually lived. In our case, our model is a binary classifier, where each risk score is either 1 (the model predicts that the patient will die) or 0 (the patient will live).
# >
# > More formally, defining _permissible pairs_ of patients as pairs where the outcomes are different, _concordant pairs_ as permissible pairs where the patient that died had a higher risk score (i.e. our model predicted 1 for the patient that died and 0 for the one that lived), and _ties_ as permissible pairs where the risk scores were equal (i.e. our model predicted 1 for both patients or 0 for both patients), the C-Index is equal to:
# >
# > $$\text{C-Index} = \frac{\#\text{concordant pairs} + 0.5\times \#\text{ties}}{\#\text{permissible pairs}}$$
#
# Run the next cell to compute the C-Index on the train and validation set (we've given you an implementation this time).

# %%
y_train_preds = dt.predict_proba(X_train_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_preds)}")


y_val_preds = dt.predict_proba(X_val_dropped)[:, 1]
print(f"Val C-Index: {cindex(y_val_dropped.values, y_val_preds)}")
# Out:
# Train C-Index: 1.0
# Val C-Index: 0.5629321808510638

# %% [markdown]
# Unfortunately your tree seems to be overfitting: it fits the training data so closely that it doesn't generalize well to other samples such as those from the validation set.
#
# > The training C-index comes out to 1.0 because, when initializing `DecisionTreeClasifier`, we have left `max_depth` and `min_samples_split` unspecified. The resulting decision tree will therefore keep splitting as far as it can, which pretty much guarantees a pure fit to the training data.
#
# To handle this, you can change some of the hyperparameters of our tree.

# %% [markdown]
# <a name='Ex-2'></a>
# ### Exercise 2
#
# Try and find a set of hyperparameters that improves the generalization to the validation set and recompute the C-index. If you do it right, you should get C-index above 0.6 for the validation set.
#
# You can refer to the documentation for the sklearn [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Try limiting the depth of the tree (<code>'max_depth'</code>).</li>
# </ul>
# </p>

# %%
# Experiment with different hyperparameters for the DecisionTreeClassifier
# until you get a c-index above 0.6 for the validation set
dt_hyperparams = {
    # set your own hyperparameters below, such as 'min_samples_split': 1

    ### START CODE HERE ###
    'max_depth': 3
    ### END CODE HERE ###
}

# %% [markdown]
# Run the next cell to fit and evaluate the regularized tree.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
dt_reg = DecisionTreeClassifier(**dt_hyperparams, random_state=10)
dt_reg.fit(X_train_dropped, y_train_dropped)

y_train_preds = dt_reg.predict_proba(X_train_dropped)[:, 1]
y_val_preds = dt_reg.predict_proba(X_val_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_preds)}")
print(f"Val C-Index (expected > 0.6): {cindex(y_val_dropped.values, y_val_preds)}")
# Out:
# Train C-Index: 0.688738755448391
# Val C-Index (expected > 0.6): 0.6302692819148936

# %% [markdown]
# If you used a low `max_depth` you can print the entire tree. This allows for easy interpretability. Run the next cell to print the tree splits.

# %%
dot_data = StringIO()
export_graphviz(dt_reg, feature_names=X_train_dropped.columns, out_file=dot_data,  
                filled=True, rounded=True, proportion=True, special_characters=True,
                impurity=False, class_names=['neg', 'pos'], precision=2)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# > **Overfitting, underfitting, and the bias-variance tradeoff**
# >
# > If you tested several values of `max_depth`, you may have seen that a value of `3` gives training and validation C-Indices of about `0.689` and `0.630`, and that a `max_depth` of `2` gives better agreement with values of about `0.653` and `0.607`. In the latter case, we have further reduced overfitting, at the cost of a minor loss in predictive performance.
# >
# > Contrast this with a `max_depth` value of `1`, which results in C-Indices of about `0.597` for the training set and `0.598` for the validation set: we have eliminated overfitting but with a much stronger degradation of predictive performance.
# >
# > Lower predictive performance on the training and validation sets is indicative of the model _underfitting_ the data: it neither learns enough from the training data nor is able to generalize to unseen data (the validation data in our case).
# >
# > Finding a model that minimizes and acceptably balances underfitting and overfitting (e.g. selecting the model with a `max_depth` of `2` over the other values) is a common problem in machine learning that is known as the _bias-variance tradeoff_.

# %% [markdown]
# <a name='6'></a>
# ## 6. Random Forests
#
# No matter how you choose hyperparameters, a single decision tree is prone to overfitting. To solve this problem, you can try **random forests**, which combine predictions from many different trees to create a robust classifier.
#
# As before, we will use scikit-learn to build a random forest for the data. We will use the default hyperparameters.

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=10)
rf.fit(X_train_dropped, y_train_dropped)
# Out:
# RandomForestClassifier(random_state=10)

# %% [markdown]
# Now compute and report the C-Index for the random forest on the training and validation set.

# %%
y_train_rf_preds = rf.predict_proba(X_train_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_rf_preds)}")

y_val_rf_preds = rf.predict_proba(X_val_dropped)[:, 1]
print(f"Val C-Index: {cindex(y_val_dropped.values, y_val_rf_preds)}")
# Out:
# Train C-Index: 1.0
# Val C-Index: 0.6660488696808511

# %% [markdown]
# Training a random forest with the default hyperparameters results in a model that has better predictive performance than individual decision trees as in the previous section, but this model is overfitting.
#
# We therefore need to tune (or optimize) the hyperparameters, to find a model that both has good predictive performance and minimizes overfitting.
#
# The hyperparameters we choose to adjust will be:
#
# - `n_estimators`: the number of trees used in the forest.
# - `max_depth`: the maximum depth of each tree.
# - `min_samples_leaf`: the minimum number (if `int`) or proportion (if `float`) of samples in a leaf.
#
# The approach we implement to tune the hyperparameters is known as a grid search:
#
# - We define a set of possible values for each of the target hyperparameters.
#
# - A model is trained and evaluated for every possible combination of hyperparameters.
#
# - The best performing set of hyperparameters is returned.
#
# The cell below implements a hyperparameter grid search, using the C-Index to evaluate each tested model.

# %%
def holdout_grid_search(clf, X_train_hp, y_train_hp, X_val_hp, y_val_hp, hyperparams, fixed_hyperparams={}):
    '''
    Conduct hyperparameter grid search on hold out validation set. Use holdout validation.
    Hyperparameters are input as a dictionary mapping each hyperparameter name to the
    range of values they should iterate over. Use the cindex function as your evaluation
    function.

    Input:
        clf: sklearn classifier
        X_train_hp (dataframe): dataframe for training set input variables
        y_train_hp (dataframe): dataframe for training set targets
        X_val_hp (dataframe): dataframe for validation set input variables
        y_val_hp (dataframe): dataframe for validation set targets
        hyperparams (dict): hyperparameter dictionary mapping hyperparameter
                            names to range of values for grid search
        fixed_hyperparams (dict): dictionary of fixed hyperparameters that
                                  are not included in the grid search

    Output:
        best_estimator (sklearn classifier): fitted sklearn classifier with best performance on
                                             validation set
        best_hyperparams (dict): hyperparameter dictionary mapping hyperparameter
                                 names to values in best_estimator
    '''
    best_estimator = None
    best_hyperparams = {}
    
    # hold best running score
    best_score = 0.0

    # get list of param values
    lists = hyperparams.values()
    
    # get all param combinations
    param_combinations = list(itertools.product(*lists))
    total_param_combinations = len(param_combinations)

    # iterate through param combinations
    for i, params in enumerate(param_combinations, 1):
        # fill param dict with params
        param_dict = {}
        for param_index, param_name in enumerate(hyperparams):
            param_dict[param_name] = params[param_index]
            
        # create estimator with specified params
        estimator = clf(**param_dict, **fixed_hyperparams)

        # fit estimator
        estimator.fit(X_train_hp, y_train_hp)
        
        # get predictions on validation set
        preds = estimator.predict_proba(X_val_hp)
        
        # compute cindex for predictions
        estimator_score = cindex(y_val_hp, preds[:,1])

        print(f'[{i}/{total_param_combinations}] {param_dict}')
        print(f'Val C-Index: {estimator_score}\n')

        # if new high score, update high score, best estimator
        # and best params 
        if estimator_score >= best_score:
                best_score = estimator_score
                best_estimator = estimator
                best_hyperparams = param_dict

    # add fixed hyperparamters to best combination of variable hyperparameters
    best_hyperparams.update(fixed_hyperparams)
    
    return best_estimator, best_hyperparams

# %% [markdown]
# <a name='Ex-3'></a>
# ### Exercise 3
#
# In the cell below, define the values you want to run the hyperparameter grid search on, and run the cell to find the best-performing set of hyperparameters.
#
# Your objective is to get a C-Index above `0.6` on both the train and validation set.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
def random_forest_grid_search(X_train_dropped, y_train_dropped, X_val_dropped, y_val_dropped):

    # Define ranges for the chosen random forest hyperparameters 
    hyperparams = {
        
        ### START CODE HERE (REPLACE array values with your code) ###

        # how many trees should be in the forest (int)
        'n_estimators': [120, 150, 180, 200],

        # the maximum depth of trees in the forest (int)
        
        'max_depth': [1, 20 , 40, 60, 80, 100],
        
        # the minimum number of samples in a leaf as a fraction
        # of the total number of samples in the training set
        # Can be int (in which case that is the minimum number)
        # or float (in which case the minimum is that fraction of the
        # number of training set samples)
        'min_samples_leaf': [3,4,5,6,7,8],

        ### END CODE HERE ###
    }

    
    fixed_hyperparams = {
        'random_state': 10,
    }
    
    rf = RandomForestClassifier

    best_rf, best_hyperparams = holdout_grid_search(rf, X_train_dropped, y_train_dropped,
                                                    X_val_dropped, y_val_dropped, hyperparams,
                                                    fixed_hyperparams)

    print(f"Best hyperparameters:\n{best_hyperparams}")

    
    y_train_best = best_rf.predict_proba(X_train_dropped)[:, 1]
    print(f"Train C-Index: {cindex(y_train_dropped, y_train_best)}")

    y_val_best = best_rf.predict_proba(X_val_dropped)[:, 1]
    print(f"Val C-Index: {cindex(y_val_dropped, y_val_best)}")
    
    # add fixed hyperparamters to best combination of variable hyperparameters
    best_hyperparams.update(fixed_hyperparams)
    
    return best_rf, best_hyperparams

# %%
best_rf, best_hyperparams = random_forest_grid_search(X_train_dropped, y_train_dropped, X_val_dropped, y_val_dropped)
# Out:
# [1/144] {'n_estimators': 120, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6543467420212766
#
# [2/144] {'n_estimators': 120, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6543467420212766
#
# [3/144] {'n_estimators': 120, 'max_depth': 1, 'min_samples_leaf': 5}
# Val C-Index: 0.6543467420212766
#
# [4/144] {'n_estimators': 120, 'max_depth': 1, 'min_samples_leaf': 6}
# Val C-Index: 0.6543467420212766
#
# [5/144] {'n_estimators': 120, 'max_depth': 1, 'min_samples_leaf': 7}
# Val C-Index: 0.6546126994680851
#
# [6/144] {'n_estimators': 120, 'max_depth': 1, 'min_samples_leaf': 8}
# Val C-Index: 0.6546126994680851
#
# [7/144] {'n_estimators': 120, 'max_depth': 20, 'min_samples_leaf': 3}
# Val C-Index: 0.6607130984042553
#
# [8/144] {'n_estimators': 120, 'max_depth': 20, 'min_samples_leaf': 4}
# Val C-Index: 0.6718916223404255
#
# [9/144] {'n_estimators': 120, 'max_depth': 20, 'min_samples_leaf': 5}
# Val C-Index: 0.6791722074468085
#
# [10/144] {'n_estimators': 120, 'max_depth': 20, 'min_samples_leaf': 6}
# Val C-Index: 0.6806848404255319
#
# [11/144] {'n_estimators': 120, 'max_depth': 20, 'min_samples_leaf': 7}
# Val C-Index: 0.6674035904255319
#
# [12/144] {'n_estimators': 120, 'max_depth': 20, 'min_samples_leaf': 8}
# Val C-Index: 0.6669714095744681
#
# [13/144] {'n_estimators': 120, 'max_depth': 40, 'min_samples_leaf': 3}
# Val C-Index: 0.6595744680851063
#
# [14/144] {'n_estimators': 120, 'max_depth': 40, 'min_samples_leaf': 4}
# Val C-Index: 0.6721908244680851
#
# [15/144] {'n_estimators': 120, 'max_depth': 40, 'min_samples_leaf': 5}
# Val C-Index: 0.6790558510638298
#
# [16/144] {'n_estimators': 120, 'max_depth': 40, 'min_samples_leaf': 6}
# Val C-Index: 0.6806848404255319
#
# [17/144] {'n_estimators': 120, 'max_depth': 40, 'min_samples_leaf': 7}
# Val C-Index: 0.6674035904255319
#
# [18/144] {'n_estimators': 120, 'max_depth': 40, 'min_samples_leaf': 8}
# Val C-Index: 0.6671210106382979
#
# [19/144] {'n_estimators': 120, 'max_depth': 60, 'min_samples_leaf': 3}
# Val C-Index: 0.6595744680851063
#
# [20/144] {'n_estimators': 120, 'max_depth': 60, 'min_samples_leaf': 4}
# Val C-Index: 0.6721908244680851
#
# [21/144] {'n_estimators': 120, 'max_depth': 60, 'min_samples_leaf': 5}
# Val C-Index: 0.6790558510638298
#
# [22/144] {'n_estimators': 120, 'max_depth': 60, 'min_samples_leaf': 6}
# Val C-Index: 0.6806848404255319
#
# [23/144] {'n_estimators': 120, 'max_depth': 60, 'min_samples_leaf': 7}
# Val C-Index: 0.6674035904255319
#
# [24/144] {'n_estimators': 120, 'max_depth': 60, 'min_samples_leaf': 8}
# Val C-Index: 0.6671210106382979
#
# [25/144] {'n_estimators': 120, 'max_depth': 80, 'min_samples_leaf': 3}
# Val C-Index: 0.6595744680851063
#
# [26/144] {'n_estimators': 120, 'max_depth': 80, 'min_samples_leaf': 4}
# Val C-Index: 0.6721908244680851
#
# [27/144] {'n_estimators': 120, 'max_depth': 80, 'min_samples_leaf': 5}
# Val C-Index: 0.6790558510638298
#
# [28/144] {'n_estimators': 120, 'max_depth': 80, 'min_samples_leaf': 6}
# Val C-Index: 0.6806848404255319
#
# [29/144] {'n_estimators': 120, 'max_depth': 80, 'min_samples_leaf': 7}
# Val C-Index: 0.6674035904255319
#
# [30/144] {'n_estimators': 120, 'max_depth': 80, 'min_samples_leaf': 8}
# Val C-Index: 0.6671210106382979
#
# [31/144] {'n_estimators': 120, 'max_depth': 100, 'min_samples_leaf': 3}
# Val C-Index: 0.6595744680851063
#
# [32/144] {'n_estimators': 120, 'max_depth': 100, 'min_samples_leaf': 4}
# Val C-Index: 0.6721908244680851
#
# [33/144] {'n_estimators': 120, 'max_depth': 100, 'min_samples_leaf': 5}
# Val C-Index: 0.6790558510638298
#
# [34/144] {'n_estimators': 120, 'max_depth': 100, 'min_samples_leaf': 6}
# Val C-Index: 0.6806848404255319
#
# [35/144] {'n_estimators': 120, 'max_depth': 100, 'min_samples_leaf': 7}
# Val C-Index: 0.6674035904255319
#
# [36/144] {'n_estimators': 120, 'max_depth': 100, 'min_samples_leaf': 8}
# Val C-Index: 0.6671210106382979
#
# [37/144] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6579787234042553
#
# [38/144] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6579787234042553
#
# [39/144] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 5}
# Val C-Index: 0.6579787234042553
#
# [40/144] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 6}
# Val C-Index: 0.6579787234042553
#
# [41/144] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 7}
# Val C-Index: 0.6580452127659574
#
# [42/144] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 8}
# Val C-Index: 0.6580452127659574
#
# [43/144] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 3}
# Val C-Index: 0.6627327127659575
#
# [44/144] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 4}
# Val C-Index: 0.6734042553191489
#
# [45/144] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 5}
# Val C-Index: 0.677908909574468
#
# [46/144] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 6}
# Val C-Index: 0.6768783244680852
#
# [47/144] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 7}
# Val C-Index: 0.6678357712765958
#
# [48/144] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 8}
# Val C-Index: 0.6692985372340425
#
# [49/144] {'n_estimators': 150, 'max_depth': 40, 'min_samples_leaf': 3}
# Val C-Index: 0.6607546542553191
#
# [50/144] {'n_estimators': 150, 'max_depth': 40, 'min_samples_leaf': 4}
# Val C-Index: 0.6734375
#
# [51/144] {'n_estimators': 150, 'max_depth': 40, 'min_samples_leaf': 5}
# Val C-Index: 0.6782081117021277
#
# [52/144] {'n_estimators': 150, 'max_depth': 40, 'min_samples_leaf': 6}
# Val C-Index: 0.6768783244680852
#
# [53/144] {'n_estimators': 150, 'max_depth': 40, 'min_samples_leaf': 7}
# Val C-Index: 0.6678357712765958
#
# [54/144] {'n_estimators': 150, 'max_depth': 40, 'min_samples_leaf': 8}
# Val C-Index: 0.6690658244680852
#
# [55/144] {'n_estimators': 150, 'max_depth': 60, 'min_samples_leaf': 3}
# Val C-Index: 0.6607546542553191
#
# [56/144] {'n_estimators': 150, 'max_depth': 60, 'min_samples_leaf': 4}
# Val C-Index: 0.6734375
#
# [57/144] {'n_estimators': 150, 'max_depth': 60, 'min_samples_leaf': 5}
# Val C-Index: 0.6782081117021277
#
# [58/144] {'n_estimators': 150, 'max_depth': 60, 'min_samples_leaf': 6}
# Val C-Index: 0.6768783244680852
#
# [59/144] {'n_estimators': 150, 'max_depth': 60, 'min_samples_leaf': 7}
# Val C-Index: 0.6678357712765958
#
# [60/144] {'n_estimators': 150, 'max_depth': 60, 'min_samples_leaf': 8}
# Val C-Index: 0.6690658244680852
#
# [61/144] {'n_estimators': 150, 'max_depth': 80, 'min_samples_leaf': 3}
# Val C-Index: 0.6607546542553191
#
# [62/144] {'n_estimators': 150, 'max_depth': 80, 'min_samples_leaf': 4}
# Val C-Index: 0.6734375
#
# [63/144] {'n_estimators': 150, 'max_depth': 80, 'min_samples_leaf': 5}
# Val C-Index: 0.6782081117021277
#
# [64/144] {'n_estimators': 150, 'max_depth': 80, 'min_samples_leaf': 6}
# Val C-Index: 0.6768783244680852
#
# [65/144] {'n_estimators': 150, 'max_depth': 80, 'min_samples_leaf': 7}
# Val C-Index: 0.6678357712765958
#
# [66/144] {'n_estimators': 150, 'max_depth': 80, 'min_samples_leaf': 8}
# Val C-Index: 0.6690658244680852
#
# [67/144] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 3}
# Val C-Index: 0.6607546542553191
#
# [68/144] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 4}
# Val C-Index: 0.6734375
#
# [69/144] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 5}
# Val C-Index: 0.6782081117021277
#
# [70/144] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 6}
# Val C-Index: 0.6768783244680852
#
# [71/144] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 7}
# Val C-Index: 0.6678357712765958
#
# [72/144] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 8}
# Val C-Index: 0.6690658244680852
#
# [73/144] {'n_estimators': 180, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6651928191489361
#
# [74/144] {'n_estimators': 180, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6651928191489361
#
# [75/144] {'n_estimators': 180, 'max_depth': 1, 'min_samples_leaf': 5}
# Val C-Index: 0.6651928191489361
#
# [76/144] {'n_estimators': 180, 'max_depth': 1, 'min_samples_leaf': 6}
# Val C-Index: 0.6651928191489361
#
# [77/144] {'n_estimators': 180, 'max_depth': 1, 'min_samples_leaf': 7}
# Val C-Index: 0.6654587765957447
#
# [78/144] {'n_estimators': 180, 'max_depth': 1, 'min_samples_leaf': 8}
# Val C-Index: 0.6654587765957447
#
# [79/144] {'n_estimators': 180, 'max_depth': 20, 'min_samples_leaf': 3}
# Val C-Index: 0.6640458776595745
#
# [80/144] {'n_estimators': 180, 'max_depth': 20, 'min_samples_leaf': 4}
# Val C-Index: 0.6726396276595744
#
# [81/144] {'n_estimators': 180, 'max_depth': 20, 'min_samples_leaf': 5}
# Val C-Index: 0.675033244680851
#
# [82/144] {'n_estimators': 180, 'max_depth': 20, 'min_samples_leaf': 6}
# Val C-Index: 0.6777094414893617
#
# [83/144] {'n_estimators': 180, 'max_depth': 20, 'min_samples_leaf': 7}
# Val C-Index: 0.6690325797872341
#
# [84/144] {'n_estimators': 180, 'max_depth': 20, 'min_samples_leaf': 8}
# Val C-Index: 0.6713098404255319
#
# [85/144] {'n_estimators': 180, 'max_depth': 40, 'min_samples_leaf': 3}
# Val C-Index: 0.6627992021276595
#
# [86/144] {'n_estimators': 180, 'max_depth': 40, 'min_samples_leaf': 4}
# Val C-Index: 0.6727892287234043
#
# [87/144] {'n_estimators': 180, 'max_depth': 40, 'min_samples_leaf': 5}
# Val C-Index: 0.6748503989361702
#
# [88/144] {'n_estimators': 180, 'max_depth': 40, 'min_samples_leaf': 6}
# Val C-Index: 0.6777759308510638
#
# [89/144] {'n_estimators': 180, 'max_depth': 40, 'min_samples_leaf': 7}
# Val C-Index: 0.6690325797872341
#
# [90/144] {'n_estimators': 180, 'max_depth': 40, 'min_samples_leaf': 8}
# Val C-Index: 0.6712267287234043
#
# [91/144] {'n_estimators': 180, 'max_depth': 60, 'min_samples_leaf': 3}
# Val C-Index: 0.6627992021276595
#
# [92/144] {'n_estimators': 180, 'max_depth': 60, 'min_samples_leaf': 4}
# Val C-Index: 0.6727892287234043
#
# [93/144] {'n_estimators': 180, 'max_depth': 60, 'min_samples_leaf': 5}
# Val C-Index: 0.6748503989361702
#
# [94/144] {'n_estimators': 180, 'max_depth': 60, 'min_samples_leaf': 6}
# Val C-Index: 0.6777759308510638
#
# [95/144] {'n_estimators': 180, 'max_depth': 60, 'min_samples_leaf': 7}
# Val C-Index: 0.6690325797872341
#
# [96/144] {'n_estimators': 180, 'max_depth': 60, 'min_samples_leaf': 8}
# Val C-Index: 0.6712267287234043
#
# [97/144] {'n_estimators': 180, 'max_depth': 80, 'min_samples_leaf': 3}
# Val C-Index: 0.6627992021276595
#
# [98/144] {'n_estimators': 180, 'max_depth': 80, 'min_samples_leaf': 4}
# Val C-Index: 0.6727892287234043
#
# [99/144] {'n_estimators': 180, 'max_depth': 80, 'min_samples_leaf': 5}
# Val C-Index: 0.6748503989361702
#
# [100/144] {'n_estimators': 180, 'max_depth': 80, 'min_samples_leaf': 6}
# Val C-Index: 0.6777759308510638
#
# [101/144] {'n_estimators': 180, 'max_depth': 80, 'min_samples_leaf': 7}
# Val C-Index: 0.6690325797872341
#
# [102/144] {'n_estimators': 180, 'max_depth': 80, 'min_samples_leaf': 8}
# Val C-Index: 0.6712267287234043
#
# [103/144] {'n_estimators': 180, 'max_depth': 100, 'min_samples_leaf': 3}
# Val C-Index: 0.6627992021276595
#
# [104/144] {'n_estimators': 180, 'max_depth': 100, 'min_samples_leaf': 4}
# Val C-Index: 0.6727892287234043
#
# [105/144] {'n_estimators': 180, 'max_depth': 100, 'min_samples_leaf': 5}
# Val C-Index: 0.6748503989361702
#
# [106/144] {'n_estimators': 180, 'max_depth': 100, 'min_samples_leaf': 6}
# Val C-Index: 0.6777759308510638
#
# [107/144] {'n_estimators': 180, 'max_depth': 100, 'min_samples_leaf': 7}
# Val C-Index: 0.6690325797872341
#
# [108/144] {'n_estimators': 180, 'max_depth': 100, 'min_samples_leaf': 8}
# Val C-Index: 0.6712267287234043
#
# [109/144] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6642453457446809
#
# [110/144] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6642453457446809
#
# [111/144] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 5}
# Val C-Index: 0.6642453457446809
#
# [112/144] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 6}
# Val C-Index: 0.6642453457446809
#
# [113/144] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 7}
# Val C-Index: 0.6647772606382979
#
# [114/144] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 8}
# Val C-Index: 0.6647772606382979
#
# [115/144] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 3}
# Val C-Index: 0.6654753989361702
#
# [116/144] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 4}
# Val C-Index: 0.672406914893617
#
# [117/144] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 5}
# Val C-Index: 0.6750166223404256
#
# [118/144] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 6}
# Val C-Index: 0.6779255319148936
#
# [119/144] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 7}
# Val C-Index: 0.6692154255319149
#
# [120/144] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 8}
# Val C-Index: 0.6723404255319149
#
# [121/144] {'n_estimators': 200, 'max_depth': 40, 'min_samples_leaf': 3}
# Val C-Index: 0.6648936170212766
#
# [122/144] {'n_estimators': 200, 'max_depth': 40, 'min_samples_leaf': 4}
# Val C-Index: 0.6724734042553191
#
# [123/144] {'n_estimators': 200, 'max_depth': 40, 'min_samples_leaf': 5}
# Val C-Index: 0.674966755319149
#
# [124/144] {'n_estimators': 200, 'max_depth': 40, 'min_samples_leaf': 6}
# Val C-Index: 0.6779753989361702
#
# [125/144] {'n_estimators': 200, 'max_depth': 40, 'min_samples_leaf': 7}
# Val C-Index: 0.6692154255319149
#
# [126/144] {'n_estimators': 200, 'max_depth': 40, 'min_samples_leaf': 8}
# Val C-Index: 0.6726063829787234
#
# [127/144] {'n_estimators': 200, 'max_depth': 60, 'min_samples_leaf': 3}
# Val C-Index: 0.6648936170212766
#
# [128/144] {'n_estimators': 200, 'max_depth': 60, 'min_samples_leaf': 4}
# Val C-Index: 0.6724734042553191
#
# [129/144] {'n_estimators': 200, 'max_depth': 60, 'min_samples_leaf': 5}
# Val C-Index: 0.674966755319149
#
# [130/144] {'n_estimators': 200, 'max_depth': 60, 'min_samples_leaf': 6}
# Val C-Index: 0.6779753989361702
#
# [131/144] {'n_estimators': 200, 'max_depth': 60, 'min_samples_leaf': 7}
# Val C-Index: 0.6692154255319149
#
# [132/144] {'n_estimators': 200, 'max_depth': 60, 'min_samples_leaf': 8}
# Val C-Index: 0.6726063829787234
#
# [133/144] {'n_estimators': 200, 'max_depth': 80, 'min_samples_leaf': 3}
# Val C-Index: 0.6648936170212766
#
# [134/144] {'n_estimators': 200, 'max_depth': 80, 'min_samples_leaf': 4}
# Val C-Index: 0.6724734042553191
#
# [135/144] {'n_estimators': 200, 'max_depth': 80, 'min_samples_leaf': 5}
# Val C-Index: 0.674966755319149
#
# [136/144] {'n_estimators': 200, 'max_depth': 80, 'min_samples_leaf': 6}
# Val C-Index: 0.6779753989361702
#
# [137/144] {'n_estimators': 200, 'max_depth': 80, 'min_samples_leaf': 7}
# Val C-Index: 0.6692154255319149
#
# [138/144] {'n_estimators': 200, 'max_depth': 80, 'min_samples_leaf': 8}
# Val C-Index: 0.6726063829787234
#
# [139/144] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 3}
# Val C-Index: 0.6648936170212766
#
# [140/144] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 4}
# Val C-Index: 0.6724734042553191
#
# [141/144] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 5}
# Val C-Index: 0.674966755319149
#
# [142/144] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 6}
# Val C-Index: 0.6779753989361702
#
# [143/144] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 7}
# Val C-Index: 0.6692154255319149
#
# [144/144] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 8}
# Val C-Index: 0.6726063829787234
#
# Best hyperparameters:
# {'n_estimators': 120, 'max_depth': 100, 'min_samples_leaf': 6, 'random_state': 10}
# Train C-Index: 0.9851098952054159
# Val C-Index: 0.6806848404255319

# %% [markdown]
# Finally, evaluate the model on the test set. This is a crucial step, as trying out many combinations of hyperparameters and evaluating them on the validation set could result in a model that ends up overfitting the validation set. We therefore need to check if the model performs well on unseen data, which is the role of the test set, which we have held out until now.

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
y_test_best = best_rf.predict_proba(X_test)[:, 1]

print(f"Test C-Index: {cindex(y_test.values, y_test_best)}")
# Out:
# Test C-Index: 0.69209737985739

# %% [markdown]
# Your C-Index on the test set should be greater than `0.6`.

# %% [markdown]
# <a name='7'></a>
# ## 7. Imputation
#
# You've now built and optimized a random forest model on our data. However, there was still a drop in test C-Index. This might be because you threw away more than half of the data of our data because of missing values for systolic blood pressure. Instead, we can try filling in, or imputing, these values.
#
# First, let's explore to see if our data is missing at random or not. Let's plot histograms of the dropped rows against each of the covariates (aside from systolic blood pressure) to see if there is a trend. Compare these to the histograms of the feature in the entire dataset. Try to see if one of the covariates has a signficantly different distribution in the two subsets.

# %%
dropped_rows = X_train[X_train.isnull().any(axis=1)]

columns_except_Systolic_BP = [col for col in X_train.columns if col not in ['Systolic BP']]

for col in columns_except_Systolic_BP:
    sns.distplot(X_train.loc[:, col], norm_hist=True, kde=False, label='full data')
    sns.distplot(dropped_rows.loc[:, col], norm_hist=True, kde=False, label='without missing data')
    plt.legend()

    plt.show()
# Out:
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# Most of the covariates are distributed similarly whether or not we have discarded rows with missing data. In other words missingness of the data is independent of these covariates.
#
# If this had been true across *all* covariates, then the data would have been said to be **missing completely at random (MCAR)**.
#
# But when considering the age covariate, we see that much more data tends to be missing for patients over 65. The reason could be that blood pressure was measured less frequently for old people to avoid placing additional burden on them.
#
# As missingness is related to one or more covariates, the missing data is said to be **missing at random (MAR)**.
#
# Based on the information we have, there is however no reason to believe that the _values_ of the missing data — or specifically the values of the missing systolic blood pressures — are related to the age of the patients.
# If this was the case, then this data would be said to be **missing not at random (MNAR)**.

# %% [markdown]
# <a name='8'></a>
# ## 8. Error Analysis
#
# <a name='Ex-4'></a>
# ### Exercise 4
# Using the information from the plots above, try to find a subgroup of the test data on which the model performs poorly. You should be able to easily find a subgroup of at least 250 cases on which the model has a C-Index of less than 0.69.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Define a mask using a feature and a threshold, e.g. patients with a BMI below 20: <code>mask = X_test['BMI'] < 20 </code>. </li>
#     <li> Try to find a subgroup for which the model had little data.</li>
# </ul>
# </p>

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def bad_subset(forest, X_test, y_test):
    # define mask to select large subset with poor performance
    # currently mask defines the entire set
    
    ### START CODE HERE (REPLACE the code after 'mask =' with your code) ###
    mask = X_test['Age'] < 32
    ### END CODE HERE ###

    X_subgroup = X_test[mask]
    y_subgroup = y_test[mask]
    subgroup_size = len(X_subgroup)

    y_subgroup_preds = forest.predict_proba(X_subgroup)[:, 1]
    performance = cindex(y_subgroup.values, y_subgroup_preds)
    
    return performance, subgroup_size

# %% [markdown]
# #### Test Your Work

# %%
performance, subgroup_size = bad_subset(best_rf, X_test, y_test)
print("Subgroup size should greater than 250, performance should be less than 0.69 ")
print(f"Subgroup size: {subgroup_size}, C-Index: {performance}")
# Out:
# Subgroup size should greater than 250, performance should be less than 0.69
# Subgroup size: 322, C-Index: 0.574468085106383

# %% [markdown]
# #### Expected Output
# Note, your actual output will vary depending on the hyper-parameters that you chose and the mask that you chose.
# - Make sure that the c-index is less than 0.69
# ```Python
# Subgroup size: 586, C-Index: 0.6275
# ```
#
# **Bonus**:
# - See if you can get a c-index as low as 0.53
# ```
# Subgroup size: 251, C-Index: 0.5331
# ```

# %% [markdown]
# <a name='9'></a>
# ## 9. Imputation Approaches
#
# Seeing that our data is not missing completely at random, we can handle the missing values by replacing them with substituted values based on the other values that we have. This is known as imputation.
#
# The first imputation strategy that we will use is **mean substitution**: we will replace the missing values for each feature with the mean of the available values. In the next cell, use the `SimpleImputer` from `sklearn` to use mean imputation for the missing values.

# %%
# Impute values using the mean
imputer = SimpleImputer(strategy='mean')
imputer.fit(X_train)
X_train_mean_imputed = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_val_mean_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)

# %% [markdown]
# <a name='Ex-5'></a>
# ### Exercise 5
# Now perform a hyperparameter grid search to find the best-performing random forest model, and report results on the test set.
#
# Define the parameter ranges for the hyperparameter search in the next cell, and run the cell.
#
# #### Target performance
# Make your test c-index at least 0.74 or higher

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
# Define ranges for the random forest hyperparameter search 
hyperparams = {
    ### START CODE HERE (REPLACE array values with your code) ###

    # how many trees should be in the forest (int)
    'n_estimators': [120, 140, 160],

    # the maximum depth of trees in the forest (int)
    'max_depth': [3,4,5,6],

    # the minimum number of samples in a leaf as a fraction
    # of the total number of samples in the training set
    # Can be int (in which case that is the minimum number)
    # or float (in which case the minimum is that fraction of the
    # number of training set samples)
    'min_samples_leaf': [2,3,4,5,6],

    ### END CODE HERE ###
}

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
rf = RandomForestClassifier

rf_mean_imputed, best_hyperparams_mean_imputed = holdout_grid_search(rf, X_train_mean_imputed, y_train,
                                                                     X_val_mean_imputed, y_val,
                                                                     hyperparams, {'random_state': 10})

print("Performance for best hyperparameters:")

y_train_best = rf_mean_imputed.predict_proba(X_train_mean_imputed)[:, 1]
print(f"- Train C-Index: {cindex(y_train, y_train_best):.4f}")

y_val_best = rf_mean_imputed.predict_proba(X_val_mean_imputed)[:, 1]
print(f"- Val C-Index: {cindex(y_val, y_val_best):.4f}")

y_test_imp = rf_mean_imputed.predict_proba(X_test)[:, 1]
print(f"- Test C-Index: {cindex(y_test, y_test_imp):.4f}")
# Out:
# [1/60] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7365760554480728
#
# [2/60] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7363534901495856
#
# [3/60] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7359854431437945
#
# [4/60] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 5}
# Val C-Index: 0.7360266991503434
#
# [5/60] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7358812174430396
#
# [6/60] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7443973257422282
#
# [7/60] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7438805399759847
#
# [8/60] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7431737594427399
#
# [9/60] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 5}
# Val C-Index: 0.743245414612009
#
# [10/60] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7432193581868203
#
# [11/60] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7467673747500212
#
# [12/60] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7487574342238117
#
# [13/60] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7476934635286046
#
# [14/60] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 5}
# Val C-Index: 0.7461908763427202
#
# [15/60] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7464666401759678
#
# [16/60] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7524769889195052
#
# [17/60] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.7532109115623216
#
# [18/60] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7524921885008653
#
# [19/60] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 5}
# Val C-Index: 0.7535474737210095
#
# [20/60] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7529872605794514
#
# [21/60] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7377507659503321
#
# [22/60] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7375651139208623
#
# [23/60] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7374858589609132
#
# [24/60] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 5}
# Val C-Index: 0.7374142037916441
#
# [25/60] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7373099780908892
#
# [26/60] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7462929306747094
#
# [27/60] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7457359745862999
#
# [28/60] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7458054583868033
#
# [29/60] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 5}
# Val C-Index: 0.7457490027988943
#
# [30/60] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7457186036361741
#
# [31/60] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7466294928333974
#
# [32/60] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7492915909401809
#
# [33/60] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7484056724837636
#
# [34/60] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 5}
# Val C-Index: 0.7475262681336434
#
# [35/60] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7476218083593354
#
# [36/60] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7515910704630878
#
# [37/60] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.7537168404847364
#
# [38/60] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7529242908852454
#
# [39/60] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 5}
# Val C-Index: 0.7532109115623216
#
# [40/60] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7527484100152213
#
# [41/60] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7386985684165728
#
# [42/60] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7386703406226183
#
# [43/60] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7384152047926451
#
# [44/60] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 5}
# Val C-Index: 0.7385704576593948
#
# [45/60] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7381709258065007
#
# [46/60] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7462505889837777
#
# [47/60] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7455025524439841
#
# [48/60] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7451377624913417
#
# [49/60] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 5}
# Val C-Index: 0.7450096517341637
#
# [50/60] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7454721532812639
#
# [51/60] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7466816056837748
#
# [52/60] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7488117184429549
#
# [53/60] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7485424687160045
#
# [54/60] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 5}
# Val C-Index: 0.7479844269432122
#
# [55/60] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7476478647845243
#
# [56/60] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7516996389013743
#
# [57/60] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.7538232375542571
#
# [58/60] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7532065688247901
#
# [59/60] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 5}
# Val C-Index: 0.7529156054101824
#
# [60/60] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7529394904666055
#
# Performance for best hyperparameters:
# - Train C-Index: 0.8407
# - Val C-Index: 0.7538
# - Test C-Index: 0.7811

# %% [markdown]
# #### Expected output
# Note, your actual c-index values will vary depending on the hyper-parameters that you choose.
# - Try to get a good Test c-index, similar these numbers below:
#
# ```Python
# Performance for best hyperparameters:
# - Train C-Index: 0.8109
# - Val C-Index: 0.7495
# - Test C-Index: 0.7805
# ```

# %% [markdown]
# Next, we will apply another imputation strategy, known as **multivariate feature imputation**, using scikit-learn's `IterativeImputer` class (see the [documentation](https://scikit-learn.org/stable/modules/impute.html#iterative-imputer)).
#
# With this strategy, for each feature that is missing values, a regression model is trained to predict observed values based on all of the other features, and the missing values are inferred using this model.
# As a single iteration across all features may not be enough to impute all missing values, several iterations may be performed, hence the name of the class `IterativeImputer`.
#
# In the next cell, use `IterativeImputer` to perform multivariate feature imputation.
#
# > Note that the first time the cell is run, `imputer.fit(X_train)` may fail with the message `LinAlgError: SVD did not converge`: simply re-run the cell.

# %%
# Impute using regression on other covariates
imputer = IterativeImputer(random_state=0, sample_posterior=False, max_iter=1, min_value=0)
imputer.fit(X_train)
X_train_imputed = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_val_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)
# Out:
# [IterativeImputer] Early stopping criterion not reached.

# %% [markdown]
# <a name='Ex-6'></a>
# ### Exercise 6
#
# Perform a hyperparameter grid search to find the best-performing random forest model, and report results on the test set. Define the parameter ranges for the hyperparameter search in the next cell, and run the cell.
#
# #### Target performance
#
# Try to get a text c-index of at least 0.74 or higher.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
# Define ranges for the random forest hyperparameter search 
hyperparams = {
    ### START CODE HERE (REPLACE array values with your code) ###

    # how many trees should be in the forest (int)
    'n_estimators': [120, 140, 160, 180],

    # the maximum depth of trees in the forest (int)
    'max_depth': [2,3,4,5,6,7],

    # the minimum number of samples in a leaf as a fraction
    # of the total number of samples in the training set
    # Can be int (in which case that is the minimum number)
    # or float (in which case the minimum is that fraction of the
    # number of training set samples)
    'min_samples_leaf': [2,3,4,5,6],

    ### END CODE HERE ###
}

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
rf = RandomForestClassifier

rf_imputed, best_hyperparams_imputed = holdout_grid_search(rf, X_train_imputed, y_train,
                                                           X_val_imputed, y_val,
                                                           hyperparams, {'random_state': 10})

print("Performance for best hyperparameters:")

y_train_best = rf_imputed.predict_proba(X_train_imputed)[:, 1]
print(f"- Train C-Index: {cindex(y_train, y_train_best):.4f}")

y_val_best = rf_imputed.predict_proba(X_val_imputed)[:, 1]
print(f"- Val C-Index: {cindex(y_val, y_val_best):.4f}")

y_test_imp = rf_imputed.predict_proba(X_test)[:, 1]
print(f"- Test C-Index: {cindex(y_test, y_test_imp):.4f}")
# Out:
# [1/120] {'n_estimators': 120, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7300901769448407
#
# [2/120] {'n_estimators': 120, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7298752114370336
#
# [3/120] {'n_estimators': 120, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7296559031916949
#
# [4/120] {'n_estimators': 120, 'max_depth': 2, 'min_samples_leaf': 5}
# Val C-Index: 0.7298306983773362
#
# [5/120] {'n_estimators': 120, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7298306983773362
#
# [6/120] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.733940013766478
#
# [7/120] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.733931328291415
#
# [8/120] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7335817379201327
#
# [9/120] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 5}
# Val C-Index: 0.7336023659234071
#
# [10/120] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7337131057304593
#
# [11/120] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.740875365604216
#
# [12/120] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7403238379377208
#
# [13/120] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.739946019772484
#
# [14/120] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 5}
# Val C-Index: 0.7394509476938979
#
# [15/120] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7397940239588829
#
# [16/120] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7445167510243432
#
# [17/120] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7433789537911013
#
# [18/120] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7423953237402261
#
# [19/120] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 5}
# Val C-Index: 0.7422151001326707
#
# [20/120] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7432508430339233
#
# [21/120] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7495912398298515
#
# [22/120] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.7486879504233084
#
# [23/120] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7488790308746924
#
# [24/120] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 5}
# Val C-Index: 0.7482015638197851
#
# [25/120] {'n_estimators': 120, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7497649493311098
#
# [26/120] {'n_estimators': 120, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.750108025596095
#
# [27/120] {'n_estimators': 120, 'max_depth': 7, 'min_samples_leaf': 3}
# Val C-Index: 0.7474698125457344
#
# [28/120] {'n_estimators': 120, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7507312084318591
#
# [29/120] {'n_estimators': 120, 'max_depth': 7, 'min_samples_leaf': 5}
# Val C-Index: 0.7473786150575739
#
# [30/120] {'n_estimators': 120, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7484078438525293
#
# [31/120] {'n_estimators': 140, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7303083995057965
#
# [32/120] {'n_estimators': 140, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7301021194730523
#
# [33/120] {'n_estimators': 140, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7299110390216681
#
# [34/120] {'n_estimators': 140, 'max_depth': 2, 'min_samples_leaf': 5}
# Val C-Index: 0.7300901769448407
#
# [35/120] {'n_estimators': 140, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7300901769448407
#
# [36/120] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7342852614002289
#
# [37/120] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7342440053936801
#
# [38/120] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7339356710289465
#
# [39/120] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 5}
# Val C-Index: 0.7340464108359986
#
# [40/120] {'n_estimators': 140, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.734011668935747
#
# [41/120] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7420305337875837
#
# [42/120] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7413964941079908
#
# [43/120] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7410881597432574
#
# [44/120] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 5}
# Val C-Index: 0.7407928535911182
#
# [45/120] {'n_estimators': 140, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7408731942354502
#
# [46/120] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7444038398485253
#
# [47/120] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7442540154036901
#
# [48/120] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7433463832596153
#
# [49/120] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 5}
# Val C-Index: 0.74318135923342
#
# [50/120] {'n_estimators': 140, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7438609976570931
#
# [51/120] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7495803829860229
#
# [52/120] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.7490939963824996
#
# [53/120] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7500016285265743
#
# [54/120] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 5}
# Val C-Index: 0.7483470455270889
#
# [55/120] {'n_estimators': 140, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7500928260147349
#
# [56/120] {'n_estimators': 140, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7499625438887911
#
# [57/120] {'n_estimators': 140, 'max_depth': 7, 'min_samples_leaf': 3}
# Val C-Index: 0.7484729849155012
#
# [58/120] {'n_estimators': 140, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.750492357867629
#
# [59/120] {'n_estimators': 140, 'max_depth': 7, 'min_samples_leaf': 5}
# Val C-Index: 0.7475154112898148
#
# [60/120] {'n_estimators': 140, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.749219935770912
#
# [61/120] {'n_estimators': 160, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7310368937266984
#
# [62/120] {'n_estimators': 160, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7309782667700239
#
# [63/120] {'n_estimators': 160, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7307958717937026
#
# [64/120] {'n_estimators': 160, 'max_depth': 2, 'min_samples_leaf': 5}
# Val C-Index: 0.7308534130659944
#
# [65/120] {'n_estimators': 160, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7309055259163719
#
# [66/120] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7351472948002232
#
# [67/120] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7353101474576529
#
# [68/120] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7350018130929193
#
# [69/120] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 5}
# Val C-Index: 0.7351603230128176
#
# [70/120] {'n_estimators': 160, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7350278695181082
#
# [71/120] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7423432108898487
#
# [72/120] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7418893948178114
#
# [73/120] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7414942057024486
#
# [74/120] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 5}
# Val C-Index: 0.7409991336238625
#
# [75/120] {'n_estimators': 160, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7411533008062292
#
# [76/120] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.743300784515535
#
# [77/120] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7434332380102445
#
# [78/120] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7430727907951336
#
# [79/120] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 5}
# Val C-Index: 0.7430510771074762
#
# [80/120] {'n_estimators': 160, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7432378148213289
#
# [81/120] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7494370726474848
#
# [82/120] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.7485620110348961
#
# [83/120] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7497779775437042
#
# [84/120] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 5}
# Val C-Index: 0.7475848950903181
#
# [85/120] {'n_estimators': 160, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7494978709729252
#
# [86/120] {'n_estimators': 160, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7503229911039022
#
# [87/120] {'n_estimators': 160, 'max_depth': 7, 'min_samples_leaf': 3}
# Val C-Index: 0.7486488657855253
#
# [88/120] {'n_estimators': 160, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7501471102338781
#
# [89/120] {'n_estimators': 160, 'max_depth': 7, 'min_samples_leaf': 5}
# Val C-Index: 0.7476804353160101
#
# [90/120] {'n_estimators': 160, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7486032670414449
#
# [91/120] {'n_estimators': 180, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7324178842617021
#
# [92/120] {'n_estimators': 180, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7323049730858842
#
# [93/120] {'n_estimators': 180, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7321421204284545
#
# [94/120] {'n_estimators': 180, 'max_depth': 2, 'min_samples_leaf': 5}
# Val C-Index: 0.7321529772722831
#
# [95/120] {'n_estimators': 180, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7321442917972202
#
# [96/120] {'n_estimators': 180, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7353372895672244
#
# [97/120] {'n_estimators': 180, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7353242613546301
#
# [98/120] {'n_estimators': 180, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7349898705647079
#
# [99/120] {'n_estimators': 180, 'max_depth': 3, 'min_samples_leaf': 5}
# Val C-Index: 0.7351581516440518
#
# [100/120] {'n_estimators': 180, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7350669541558913
#
# [101/120] {'n_estimators': 180, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7424148660591177
#
# [102/120] {'n_estimators': 180, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7420696184253668
#
# [103/120] {'n_estimators': 180, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7418220823860737
#
# [104/120] {'n_estimators': 180, 'max_depth': 4, 'min_samples_leaf': 5}
# Val C-Index: 0.7416288305659239
#
# [105/120] {'n_estimators': 180, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7416766006787698
#
# [106/120] {'n_estimators': 180, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7437220300560865
#
# [107/120] {'n_estimators': 180, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7442236162409698
#
# [108/120] {'n_estimators': 180, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7441953884470154
#
# [109/120] {'n_estimators': 180, 'max_depth': 5, 'min_samples_leaf': 5}
# Val C-Index: 0.7432725567215805
#
# [110/120] {'n_estimators': 180, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7435808910863141
#
# [111/120] {'n_estimators': 180, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7498822032444592
#
# [112/120] {'n_estimators': 180, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.7489376578313671
#
# [113/120] {'n_estimators': 180, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.750524928399115
#
# [114/120] {'n_estimators': 180, 'max_depth': 6, 'min_samples_leaf': 5}
# Val C-Index: 0.7485967529351477
#
# [115/120] {'n_estimators': 180, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7497497497497497
#
# [116/120] {'n_estimators': 180, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7509526880459635
#
# [117/120] {'n_estimators': 180, 'max_depth': 7, 'min_samples_leaf': 3}
# Val C-Index: 0.7497540924872812
#
# [118/120] {'n_estimators': 180, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7510873129094388
#
# [119/120] {'n_estimators': 180, 'max_depth': 7, 'min_samples_leaf': 5}
# Val C-Index: 0.7483883015336378
#
# [120/120] {'n_estimators': 180, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7491026818575626
#
# Performance for best hyperparameters:
# - Train C-Index: 0.8696
# - Val C-Index: 0.7511
# - Test C-Index: 0.7849

# %% [markdown]
# #### Expected Output
# Note, your actual output will vary depending on the hyper-parameters that you chose and the mask that you chose.
# ```Python
# Performance for best hyperparameters:
# - Train C-Index: 0.8131
# - Val C-Index: 0.7454
# - Test C-Index: 0.7797
# ```

# %% [markdown]
# <a name='10'></a>
# ## 10. Comparison
#
# For good measure, retest on the subgroup from before to see if your new models do better.

# %%
performance, subgroup_size = bad_subset(best_rf, X_test, y_test)
print(f"C-Index (no imputation): {performance}")

performance, subgroup_size = bad_subset(rf_mean_imputed, X_test, y_test)
print(f"C-Index (mean imputation): {performance}")

performance, subgroup_size = bad_subset(rf_imputed, X_test, y_test)
print(f"C-Index (multivariate feature imputation): {performance}")
# Out:
# C-Index (no imputation): 0.574468085106383
# C-Index (mean imputation): 0.5502659574468085
# C-Index (multivariate feature imputation): 0.5706560283687944

# %% [markdown]
# We should see that avoiding complete case analysis (i.e. analysis only on observations for which there is no missing data) allows our model to generalize a bit better. Remember to examine your missing cases to judge whether they are missing at random or not!

# %% [markdown]
# <a name='11'></a>
# ## 11. Explanations: SHAP
#
# Using a random forest has improved results, but we've lost some of the natural interpretability of trees. In this section we'll try to explain the predictions using slightly more sophisticated techniques.
#
# You choose to apply **SHAP (SHapley Additive exPlanations) **, a cutting edge method that explains predictions made by black-box machine learning models (i.e. models which are too complex to be understandable by humans as is).
#
# > Given a prediction made by a machine learning model, SHAP values explain the prediction by quantifying the additive importance of each feature to the prediction. SHAP values have their roots in cooperative game theory, where Shapley values are used to quantify the contribution of each player to the game.
# >
# > Although it is computationally expensive to compute SHAP values for general black-box models, in the case of trees and forests there exists a fast polynomial-time algorithm. For more details, see the [TreeShap paper](https://arxiv.org/pdf/1802.03888.pdf).
#
# We'll use the [shap library](https://github.com/slundberg/shap) to do this for our random forest model. Run the next cell to output the most at risk individuals in the test set according to our model.

# %%
X_test_risk = X_test.copy(deep=True)
X_test_risk.loc[:, 'risk'] = rf_imputed.predict_proba(X_test_risk)[:, 1]
X_test_risk = X_test_risk.sort_values(by='risk', ascending=False)
X_test_risk.head()
# Out:
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 5493  67.0          80.0           30.0   1.0             77.7
# 6337  69.0          80.0          233.0   1.0             77.7
# 2608  71.0          80.0          104.0   1.0             43.8
# 864   74.0         110.0          105.0   1.0             46.9
# 2044  74.0          80.0           83.0   1.0             47.6
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 5493                59.0            3.4              231.0        36.0
# 6337                48.0            4.2              159.0        87.0
# 2608                23.0            4.0              201.0       119.0
# 864                 45.0            4.4              233.0       102.0
# 2044                19.0            4.2              205.0        72.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 5493             1.40            6.3  1.0        170.0  202.0  17.8
# 6337             1.81            6.9  1.0        146.0  291.0  29.9
# 2608             1.60            7.0  1.0        166.0  311.0  38.3
# 864              1.70            7.3  1.0        180.0  283.0  36.0
# 2044             1.71            6.9  1.0        180.0  310.0  23.2
#
#       White blood cells        BMI  Pulse pressure      risk
# 5493                8.4  17.029470            90.0  0.709406
# 6337               15.2  17.931276            66.0  0.636444
# 2608                6.3  17.760766            86.0  0.581104
# 864                 9.2  26.906341            70.0  0.575972
# 2044               10.8  20.900101           100.0  0.568929

# %% [markdown]
# We can use SHAP values to try and understand the model output on specific individuals using force plots. Run the cell below to see a force plot on the riskiest individual.

# %%
explainer = shap.TreeExplainer(rf_imputed)
i = 0
shap_value = explainer.shap_values(X_test.loc[X_test_risk.index[i], :])[1]
shap.force_plot(explainer.expected_value[1], shap_value, feature_names=X_test.columns, matplotlib=True)

# %% [markdown]
# How to read this chart:
# - The red sections on the left are features which push the model towards the final prediction in the positive direction (i.e. a higher Age increases the predicted risk).
# - The blue sections on the right are features that push the model towards the final prediction in the negative direction (if an increase in a feature leads to a lower risk, it will be shown in blue).
# - Note that the exact output of your chart will differ depending on the hyper-parameters that you choose for your model.
#
# We can also use SHAP values to understand the model output in aggregate. Run the next cell to initialize the SHAP values (this may take a few minutes).

# %%
shap_values = shap.TreeExplainer(rf_imputed).shap_values(X_test)[1]

# %% [markdown]
# Run the next cell to see a summary plot of the SHAP values for each feature on each of the test examples. The colors indicate the value of the feature.

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# Clearly we see that being a woman (`sex = 2.0`, as opposed to men for which `sex = 1.0`) has a negative SHAP value, meaning that it reduces the risk of dying within 10 years. High age and high systolic blood pressure have positive SHAP values, and are therefore related to increased mortality.
#
# You can see how features interact using dependence plots. These plot the SHAP value for a given feature for each data point, and color the points in using the value for another feature. This lets us begin to explain the variation in SHAP value for a single value of the main feature.
#
# Run the next cell to see the interaction between Age and Sex.

# %%
shap.dependence_plot('Age', shap_values, X_test, interaction_index='Sex')
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# We see that while Age > 50 is generally bad (positive SHAP value), being a woman generally reduces the impact of age. This makes sense since we know that women generally live longer than men.
#
# Let's now look at poverty index and age.

# %%
shap.dependence_plot('Poverty index', shap_values, X_test, interaction_index='Age')

# %% [markdown]
# We see that the impact of poverty index drops off quickly, and for higher income individuals age begins to explain much of variation in the impact of poverty index.
#
# Try some other pairs and see what other interesting relationships you can find!

# %% [markdown]
# # Congratulations!
#
# You have completed the second assignment in Course 2. Along the way you've learned to fit decision trees, random forests, and deal with missing data. Now you're ready to move on to week 3!
